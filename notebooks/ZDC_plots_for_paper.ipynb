# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, matplotlib as mpl
#!pip install -n tensorflow mplhep
import mplhep as hep
hep.style.use("CMS")
plt.rcParams['figure.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
plt.rcParams['savefig.bbox']='tight'
plt.rcParams['legend.frameon']=True
plt.rcParams['legend.edgecolor']='white'
import uproot,glob


plt.rcParams["figure.figsize"] = (10, 8)
from matplotlib.backends.backend_pdf import PdfPages

# %%
path="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/*.csv"
dfs=[]
for file in glob.glob(path):
    df=pd.read_csv(file)
    print("read file:", file)
    if "z_truth_w0_5pt0" in df.columns:
        dfs.append(df)
        print("added file", file)
df_h4=pd.concat(dfs)
del dfs
# Out:
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325581_34.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325581_34.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325595_48.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325595_48.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325579_32.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325579_32.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325551_4.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325551_4.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325564_17.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325564_17.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325574_27.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325574_27.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325556_9.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325556_9.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325586_39.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325586_39.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325561_14.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325561_14.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325555_8.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325555_8.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325550_3.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325550_3.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325572_25.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325572_25.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325575_28.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325575_28.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325552_5.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325552_5.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325593_46.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325593_46.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325549_2.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325549_2.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325548_1.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325548_1.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325576_29.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325576_29.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325547_0.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325547_0.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325562_15.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325562_15.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325584_37.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325584_37.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325594_47.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325594_47.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325589_42.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325589_42.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325590_43.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325590_43.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325577_30.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325577_30.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325566_19.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325566_19.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325554_7.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325554_7.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325563_16.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325563_16.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325571_24.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325571_24.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325567_20.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325567_20.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325587_40.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325587_40.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325592_45.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325592_45.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325578_31.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325578_31.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325573_26.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325573_26.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325582_35.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325582_35.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325591_44.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325591_44.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325558_11.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325558_11.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325553_6.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325553_6.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325583_36.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325583_36.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325585_38.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325585_38.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325570_23.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325570_23.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325568_21.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325568_21.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325569_22.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325569_22.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325559_12.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325559_12.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325580_33.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325580_33.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325565_18.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325565_18.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325560_13.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325560_13.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325546_49.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325546_49.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325588_41.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325588_41.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325557_10.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1325557_10.edm4hep.root.csv

# %%
path="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV//*.csv"
dfs=[]
for file in glob.glob(path):
    df=pd.read_csv(file)
    print("read file:", file)
    if "x_truth_w0_5pt0" in df.columns:
        dfs.append(df)
        print("added file", file)
df_h4_gamma_Fe=pd.concat(dfs)
del dfs
# Out:
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093480_45.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093480_45.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093509_74.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093509_74.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093492_57.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093492_57.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093506_71.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093506_71.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093483_48.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093483_48.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093442_7.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093442_7.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093441_6.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093441_6.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093514_79.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093514_79.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093533_98.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093533_98.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093491_56.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093491_56.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093461_26.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093461_26.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093484_49.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093484_49.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093476_41.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093476_41.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093460_25.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093460_25.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093501_66.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093501_66.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093458_23.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093458_23.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093505_70.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093505_70.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093447_12.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093447_12.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093439_4.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093439_4.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093448_13.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093448_13.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093434_99.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093434_99.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093451_16.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093451_16.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093518_83.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093518_83.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093523_88.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093523_88.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093446_11.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093446_11.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093438_3.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093438_3.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093488_53.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093488_53.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093515_80.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093515_80.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093463_28.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093463_28.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093500_65.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093500_65.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093457_22.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093457_22.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093482_47.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093482_47.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093453_18.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093453_18.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093475_40.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093475_40.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093521_86.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093521_86.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093512_77.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093512_77.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093469_34.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093469_34.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093472_37.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093472_37.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093467_32.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093467_32.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093452_17.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093452_17.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093524_89.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093524_89.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093456_21.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093456_21.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093493_58.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093493_58.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093529_94.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093529_94.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093440_5.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093440_5.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093517_82.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093517_82.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093526_91.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093526_91.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093531_96.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093531_96.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093485_50.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093485_50.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093464_29.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093464_29.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093486_51.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093486_51.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093465_30.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093465_30.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093498_63.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093498_63.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093525_90.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093525_90.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093445_10.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093445_10.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093490_55.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093490_55.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093522_87.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093522_87.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093473_38.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093473_38.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093468_33.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093468_33.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093494_59.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093494_59.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093530_95.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093530_95.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093455_20.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093455_20.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093499_64.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093499_64.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093507_72.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093507_72.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093528_93.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093528_93.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093502_67.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093502_67.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093449_14.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093449_14.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093459_24.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093459_24.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093489_54.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093489_54.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093466_31.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093466_31.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093450_15.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093450_15.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093519_84.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093519_84.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093437_2.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093437_2.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093444_9.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093444_9.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093477_42.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093477_42.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093474_39.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093474_39.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093532_97.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093532_97.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093436_1.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093436_1.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093470_35.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093470_35.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093487_52.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093487_52.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093478_43.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093478_43.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093454_19.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093454_19.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093508_73.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093508_73.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093462_27.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093462_27.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093520_85.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093520_85.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093511_76.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093511_76.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093504_69.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093504_69.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093503_68.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093503_68.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093443_8.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093443_8.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093471_36.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093471_36.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093527_92.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093527_92.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093495_60.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093495_60.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093435_0.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093435_0.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093496_61.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093496_61.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093516_81.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093516_81.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093479_44.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093479_44.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093513_78.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093513_78.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093510_75.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093510_75.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093497_62.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093497_62.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093481_46.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_800MeV/zdc_reco_gamma_discrete_10GeV-300GeV_theta_0deg-0.23deg_1093481_46.edm4hep.root.csv

# %%
path="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV//*.csv"
dfs=[]
for file in glob.glob(path):
    df_h1=pd.read_csv(file)
    print("read file:", file)
    if "z_truth_w0_5pt0" in df.columns:
        dfs.append(df_h1)
        print("added file", file)
df_h1=pd.concat(dfs)
# Out:
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396346_7.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396346_7.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396366_27.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396366_27.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396378_39.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396378_39.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396340_1.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396340_1.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396339_0.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396339_0.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396371_32.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396371_32.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396373_34.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396373_34.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396353_14.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396353_14.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396368_29.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396368_29.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396343_4.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396343_4.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396376_37.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396376_37.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396361_22.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396361_22.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396342_3.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396342_3.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396359_20.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396359_20.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396369_30.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396369_30.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396362_23.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396362_23.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396352_13.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396352_13.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396377_38.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396377_38.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396367_28.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396367_28.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396354_15.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396354_15.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396365_26.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396365_26.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396370_31.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396370_31.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396363_24.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396363_24.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396355_16.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396355_16.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396372_33.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396372_33.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396348_9.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396348_9.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396351_12.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396351_12.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396341_2.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396341_2.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396349_10.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396349_10.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396350_11.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396350_11.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396345_6.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396345_6.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396356_17.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396356_17.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396375_36.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396375_36.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396357_18.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396357_18.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396338_49.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396338_49.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396360_21.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396360_21.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396358_19.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396358_19.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396344_5.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396344_5.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396364_25.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396364_25.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396374_35.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396374_35.edm4hep.root.csv
# read file: /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396347_8.edm4hep.root.csv
# added file /home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h1_neutron_Fe_800MeV/reco_neutron_discrete_10GeV-300GeV_theta_0.0deg-0.3deg_1396347_8.edm4hep.root.csv

# %%
#private communication from Alex Jentsch
z_front_face=35.8

# %%
from scipy.optimize import curve_fit

def gauss(x, A,mu, sigma):
    return A * np.exp(-(x-mu)**2/(2*sigma**2))
#do just the calculation of the resolution
def res_calc(a, fnc=gauss, bins=None, nsigma=2, quantile=None):
    a=np.array(a)
    mean=np.mean(a)
    sigma=np.std(a)
    if bins is None :
        if quantile==None:
            bins = np.linspace(mean-3*sigma,mean+3*sigma, 20)
        else:
            bins = np.linspace(np.quantile(a, quantile),np.quantile(a, 1-quantile), 20)
    h,x=np.histogram(a, bins=bins)
    bc=(x[1:]+x[:-1])/2
    a_in_window=a[(a>=x[0])&(a<=x[-1])]
    p0=[10,np.mean(a_in_window), np.std(a_in_window)*.9]
    slc=np.abs(bc-np.mean(a_in_window))<nsigma*np.std(a_in_window)
    try:
        coeff, var_matrix = curve_fit(fnc, bc[slc], h[slc], p0=p0,
                                 sigma=np.sqrt(h[slc]))
        return abs(coeff[2]),np.sqrt(var_matrix[2][2]),coeff[1], np.sqrt(var_matrix[1][1])
    except:
        return 0, 0,0,0

# %%
for df in df_h4, df_h1, df_h4_gamma_Fe, :
    df['x_truth_face'] = df.eval(f'x_truth_w0_5pt75/z_truth_w0_5pt75*{z_front_face*1000}')
    df['y_truth_face'] = df.eval(f'y_truth_w0_5pt75/z_truth_w0_5pt75*{z_front_face*1000}')
    df['theta_mrad']=df.eval(f"sqrt(x_truth_face**2+y_truth_face**2)/{z_front_face}")

# %%
import compress_pickle as pickle
# path_indv='/home/sebouh/test_train/Block_20230907_1712_concatTrue'  
# path_indv='/home/sebouh/test_train/Block_20230911_1238_concatTrue'  
# path_indv='/home/sebouh/test_train/Block_20230912_1642_concatTrue' 
# path_indv='/home/sebouh/test_train/Block_20230912_2206_concatTrue'
# path_indv='/home/sebouh/test_train/Block_20230913_0740_concatTrue'
dfs_AI={}
for abso in "Fe".split():
    if abso=="Fe":
        path_indv="/home/ryan/zdc_studies/results/results_4D_output2D_zdc_h4_neutron_graphnet_correctdynamicrange/ECCE_20240129-1333_graphnet_4D"
        path_preprocessed="/home/ryan/zdc_studies/preprocessed_data/preprocessed_input4D_output2D_zdc_h4_neutron_graphnet_energy0.5_theta0.5_correctdynamicrange/"
    elif abso=="Pb":
        path_indv='/media/miguel/Elements/bishnu/zdc_models/results_input4D_output2D_Pb_zdc/ECCE_20230920-0650_deepsets_4D/'
    
    if len(glob.glob(path_indv+"/test_predictions.npz"))>0:
        npz_unpacked = np.load(path_indv+"/test_predictions.npz")
    else: 
        #use the most recent version of the predictions, even though that's cheating
        
        npz_unpacked = np.load(path_indv+"/predictions.npz")
    
    
    ## For 2 D nhits
    
    #path_to_result_indv=path_indv.replace("results_", "preprocessed_input")
    #path_to_result_indv="/".join(path_to_result_indv.split("/")[:-1])
    #print(path_to_result_indv)
    path_to_result_indv=path_preprocessed
    
    #print(dict(npz_unpacked).keys())
    #print(dict(npz_unpacked)['meta'])
    predictions = npz_unpacked['outputs']  ### predicted value of the energy
    targets = npz_unpacked['targets']      ### true value of the energy
    
    means = pickle.load(open(f"{path_to_result_indv}/means.p", 'rb'), compression='gzip')
    stdvs = pickle.load(open(f"{path_to_result_indv}/stdvs.p", 'rb'), compression='gzip')

    #print(targets)
    print(stdvs)
    targets_plt_energy     = targets[:,0]*stdvs['genP'] + means['genP']
    predictions_plt_energy = predictions[:,0]*stdvs['genP'] + means['genP']

    #cheating here since I know the distribution that these events came from 
    #if 'theta' not in stdvs:
    #    stdvs['theta']=1.171
    #    means['theta']=2.012
    ### True x
#     targets_plt_x      = targets[2]*stdvs['.position.x'] + means['.position.x']
#     print(targets_plt_x)
#     ### Predicted x
#     predictions_plt_x  = predictions[2]*stdvs['.position.x'] + means['.position.x']

#     ### True y
#     targets_plt_y      = targets[3]*stdvs['.position.y'] + means['.position.y']
#     ### Predicted x
#     predictions_plt_y  = predictions[3]*stdvs['.position.y'] + means['.position.y']

#     ### True z
#     targets_plt_z      = targets[1]*stdvs['.position.z'] + means['.position.z']
#     ### Predicted z
#     predictions_plt_z  = predictions[1]*stdvs['.position.z'] + means['.position.z']
    
    include_phi=len(targets[0]) >2
    #include_phi=True
    print("include_phi", include_phi)
    if include_phi:
        ### True PHI
        targets_plt_phi      = targets[2]*stdvs['phi'] + means['phi']
        ### Predicted PHI
        predictions_plt_phi  = predictions[2]*stdvs['phi'] + means['phi']
        
    include_theta=len(targets[0]) >1

    if include_theta:
        ### True PHI
        targets_plt_theta      = targets[:,1]*stdvs['theta'] + means['theta']
        ### Predicted PHI
        predictions_plt_theta  = predictions[:,1]*stdvs['theta'] + means['theta']
    
    targets_plt_energy     = 10**targets_plt_energy
    predictions_plt_energy = 10**predictions_plt_energy
    
    import pandas as pd
    dfs_AI[abso]=pd.DataFrame({"E_truth":targets_plt_energy, "E_reco":predictions_plt_energy, 
                  "theta_truth":targets_plt_theta, "theta_reco":predictions_plt_theta,
                 })
    
    if include_phi:
        dfs_AI[abso]["phi_truth"]=targets_plt_phi
        dfs_AI[abso]["phi_reco"]=predictions_plt_phi
        
        print("phi truth", targets_plt_phi)
        print("phi reco", predictions_plt_phi)        
        print("theta truth", targets_plt_theta)
        print("theta reco", predictions_plt_theta)
deg=np.pi/180
mrad=0.001
if include_phi:
    for df_AI in dfs_AI.values():
        df_AI['x_truth_face'] = df_AI.eval(f'cos(phi_truth*{mrad})*sin(theta_truth*{mradad})/cos(theta_truth*{mrad})*{z_front_face*1000}')
        df_AI['y_truth_face'] = df_AI.eval(f'sin(phi_truth*{mrad})*sin(theta_truth*{mrad})/cos(theta_truth*{mrad})*{z_front_face*1000}')
        df_AI['x_reco_face'] = df_AI.eval(f'cos(phi_reco*{mrad})*sin(theta_reco*{mrad})/cos(theta_reco*{mrad})*{z_front_face*1000}')
        df_AI['y_reco_face'] = df_AI.eval(f'sin(phi_reco*{mrad})*sin(theta_reco*{mrad})/cos(theta_reco*{mrad})*{z_front_face*1000}')
        df_AI["dist_from_edge"]=df_AI.eval("(300-abs(y_truth_face))*(300-abs(y_truth_face)<300-abs(x_truth_face))"+
                            "+(300-abs(x_truth_face))*(300-abs(y_truth_face)>300-abs(x_truth_face))")

for df_AI in dfs_AI.values():
    print(df_AI)
    df_AI['theta_mrad'] = df_AI.eval(f"theta_truth")
    df_AI['mc_pz']=df_AI["E_truth"]
# Out:
# {'ZDCHcalHitsReco.energy': 0.5242519519924232, '.position.z': 1724.2732334939615, '.position.x': 123.52777785267233, '.position.y': 123.48914625013197, 'clusterE': 0.4593812412035674, 'genP': 0.42628727659773313, 'theta': 1.5254436518121897}
# include_phi False
#            E_truth      E_reco  theta_truth  theta_reco
# 0        11.121423   11.170097     3.521048    3.594000
# 1       294.914276  292.265717     1.291871    1.302101
# 2        11.247420   11.432027     4.114334    4.362636
# 3        17.376244   18.737818     3.996757    4.019634
# 4        37.065754   40.925629     0.913491    0.829224
# ...            ...         ...          ...         ...
# 363358  167.997452  168.358078     3.829198    3.813768
# 363359   84.892738   83.660881     4.645096    4.710867
# 363360   10.438409   10.752369     3.604695    3.483088
# 363361   76.775711   79.457397     2.392080    2.366799
# 363362  208.350250  197.829422     3.571471    3.565347
#
# [363363 rows x 4 columns]

# %%
def res_plot(df, label=f"ZDC (64 Fe) with HEXPLIT, H4 staggering", fit=True, nEnergyBins=15,shift=0, abs=False,alt_residual=False, 
            use_dr=True,
            direction='r', rw="_rw", w0_params=(5.0,0.65,0.31), quantile=None, **arg):
    energy_bins=np.exp(np.linspace(np.log(10), np.log(300), nEnergyBins))
    
    bcs=[]
    sigmas=[]
    dsigmas=[]
    mus=[]
    dmus=[]
    
    for j in range(len(energy_bins)-1):
        dfq=df.query(f"mc_pz>{energy_bins[j]} and mc_pz<{energy_bins[j+1]} and theta_mrad<4")
        if len(dfq)==0:
            continue
        l=np.log((energy_bins[j]+energy_bins[j+1])/2/50)
        #w0=5.0+0.65*l+0.31*l*l
        w0=w0_params[0]+w0_params[1]*l+w0_params[2]*l*l
        w0str=f'{int(w0*4)/4}'.replace('.', 'pt')
        #x=dfq[f'x_truth_face']
        if alt_residual :
            dx=dfq.eval(f'dx{rw}_w0_{w0str}/z_truth_w0_{w0str}*{z_front_face*1000}')
            dy=dfq.eval(f'dy{rw}_w0_{w0str}/z_truth_w0_{w0str}*{z_front_face*1000}')
            dr=(dx*dfq.eval("x_truth_face")+dy*dfq.eval("y_truth_face"))/dfq.eval("sqrt(x_truth_face**2+y_truth_face**2)")
        elif use_dr:
            dr=dfq[f'dr{rw}_w0_{w0str}']
        else:
            dr=dfq.eval(f"(theta_reco-theta_truth)*{z_front_face}")
            #dx=dfq.eval("x_reco_face-x_truth_face"); dy=dfq.eval("y_reco_face-y_truth_face")
            #dr=(dx*dfq.eval("x_truth_face")+dy*dfq.eval("y_truth_face"))/dfq.eval("sqrt(x_truth_face**2+y_truth_face**2)")
            
        a=dr
        print("sigma(dr)=", np.std(a))
        #if abs:
        #    a*=np.sign(x)
        a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
        
        bcs.append((energy_bins[j]+energy_bins[j+1])/2)
        sigma,dsigma,mu, dmu=res_calc(a, nsigma=2, quantile=quantile)
        sigmas.append(sigma)
        dsigmas.append(dsigma)
        mus.append(mu)
        dmus.append(dmu)
    
    plt.errorbar(np.array(bcs)*(1+shift), sigmas, dsigmas,label=label, marker='o', ls='', **arg)
    print(f"Energies={bcs} #GeV")
    print(f"sigma_thetas={list(np.array(sigmas)/z_front_face)} #mrad")
    print(f"dsigma_thetas={list(np.array(dsigmas)/z_front_face)} #mrad")
  
    
    
    plt.xlabel("Energy [GeV]")
    if direction=="phi":
        plt.ylabel("$\\sigma[r(\\phi_{\\rm recon}-\\phi_{\\rm truth})]$ [mm]")
    else:
        plt.ylabel("$\sigma_r$ [mm]")
    plt.ylim(0)
    return np.array(bcs), np.array(sigmas),np.array(dsigmas), np.array(mus), np.array(dmus)
    
def yr_req(label='YR requirement: $\\frac{3\,\, mrad}{\\sqrt{E}}$',
          **arg):    
    #YR requirement
    x=np.linspace(10, 300,100)
    y=3/np.sqrt(x)*z_front_face
    plt.errorbar(x,y, label=label, **arg, marker='')

def write_geom(name="Fe",y=0.5,x=10, **arg):
    txt={"Fe":"Fe 20 mm\nSc 3.0 mm\n(64 layers)\ncell area 25 cm$^2$",
        "Pb":"Pb 10 mm\nSc 2.5 mm\n(110 layers)"}[name]
    plt.text(x, y, txt, fontsize=18,**arg)

def theta_axis():    
    #plt.legend()
    
    ax1=plt.gca()
    
    ax1.set_ylabel("$\sigma_r$ [mm]")
    
    ax2=plt.gca().twinx()
    ax2.set_ylim(ax1.get_ylim()[0]/z_front_face,ax1.get_ylim()[1]/z_front_face)
    
    ax2.set_ylabel("$\\sigma_\\theta$ [mrad]")
    return ax2

def fit_res(bcs, sigmas,dsigmas, minE=0):
    P0=[10,2]
    fnc = lambda E, b,c: np.sqrt(b**2/E+c**2)
    P, cov =curve_fit(fnc,bcs[bcs>minE], sigmas[bcs>minE], p0=P0, sigma=dsigmas[bcs>minE] if dsigmas is not None else None)
    x=np.linspace(8, 300,100)
    label="(%.2f\\pm %.2f)/\\sqrt{E}\\oplus\,(%.2f\\pm %.2f)$ mrad"%\
                                        (P[0]/z_front_face, np.sqrt(cov[0][0])/z_front_face, 
                                        P[1]/z_front_face, np.sqrt(cov[1][1])/z_front_face)
    
    print(label)
    label=f"fit: ${P[0]/z_front_face:.2f}/\\sqrt{{E}}\\,\\oplus\\,{P[1]/z_front_face:.2f}$ mrad"
                                        
    plt.errorbar(x, fnc(x,*P), label=label, color='purple', marker='',ls=':')

def fit_res_stoch_only(bcs, sigmas,dsigmas, minE=0):
    P0=[10]
    fnc = lambda E, b: b/np.sqrt(E)
    P, cov =curve_fit(fnc,bcs[bcs>minE], sigmas[bcs>minE], p0=P0, sigma=dsigmas[bcs>minE] if dsigmas is not None else None)
    x=np.linspace(8, 300,100)
    
    label=f"fit: ${P[0]/z_front_face:.2f}/\\sqrt{{E}}$ mrad"
    print(label)
                                        
    plt.errorbar(x, fnc(x,*P), label=label, color='purple', marker='',ls=':')

def fit_res_inv_stoch(bcs, sigmas,dsigmas):
    P0=[10,2]
    fnc = lambda E, a,b: np.sqrt(a**2/E**2+b**2/E)
    P, cov =curve_fit(fnc,bcs, sigmas, p0=P0, sigma=dsigmas)
    x=np.linspace(8, 300,100)
    label="(%.2f\\pm %.2f)/\\sqrt{E}\\oplus\,(%.2f\\pm %.2f)$ mrad"%\
                                        (P[0]/z_front_face, np.sqrt(cov[0][0])/z_front_face, 
                                        P[1]/z_front_face, np.sqrt(cov[1][1])/z_front_face)
    
    print(label)
    label=f"fit: ${P[0]/z_front_face:.2f}/E\\,\\oplus\\,{P[1]/z_front_face:.2f}/\\sqrt{{E}}$ mrad"
                                        
    plt.errorbar(x, fnc(x,*P), label=label, color='purple', marker='',ls=':')
fig = plt.figure()

res_plot(df_h1, label="unstaggered", rw="", w0_params=(5.9,0.33,0.0), fit=False, color='tab:blue', fillstyle='none', shift=0)

res_plot(df_h4, label="staggered, baseline", rw="", w0_params=(4.2,0.045,0.32), fit=False, color='tab:orange', fillstyle='none', shift=0.007*3)
ret=res_plot(df_h4, label="staggered, HEXPLIT", color='tab:green', fillstyle='full', shift=0.007*4)
#(*ret)
#fit_res(*(ret[:3]), minE=80)
#fit_res_inv_stoch(*(ret[:3]))


#Bishnu's numbers
##------------THETA REGRESSION PARAMETERS---------------------------------------
##--Detector = zdc,   Absorber =64Fe,  input = 64Zseg,  output = 3D,     Model=graphnet,  ECAL Status=False
gnn_energy_Input64Zseg_output3D_zdc_64Fe=np. array([ 10.,  11.,  12.,  13.,  14.,  16.,  17.,  19.,  21.,  24.,  26.,
        29.,  32.,  35.,  39.,  43.,  47.,  52.,  57.,  63.,  70.,  77.,
        85.,  93., 103., 114., 125., 138., 152., 168., 185., 204., 225.,
       248., 274.])
gnn_theta_res_fit_Input64Zseg_output3D_zdc_64Fe=np. array([0.214664, 0.207316, 0.197218, 0.185306, 0.175127, 0.16065 ,
       0.156735, 0.151047, 0.143546, 0.134766, 0.125774, 0.117181,
       0.115651, 0.107514, 0.104951, 0.097164, 0.098249, 0.09131 ,
       0.085207, 0.085866, 0.076467, 0.073615, 0.072934, 0.070036,
       0.066807, 0.064527, 0.059164, 0.058777, 0.057299, 0.054317,
       0.055537, 0.05096 , 0.05005 , 0.049701, 0.049169])


#plt.errorbar(gnn_energy_Input64Zseg_output3D_zdc_64Fe, gnn_theta_res_fit_Input64Zseg_output3D_zdc_64Fe*z_front_face,
#            color='r', label="staggered, GNN", marker='s', ls='')


#fit_res(gnn_energy_Input64Zseg_output3D_zdc_64Fe, gnn_theta_res_fit_Input64Zseg_output3D_zdc_64Fe*z_front_face, None)
#yr_req(ls='--', color='tab:brown')

##------------PHI REGRESSION PARAMETERS---------------------------------------
##--Detector = zdc,   Absorber =64Fe,  input = 64Zseg,  output = 3D,     Model=graphnet,  ECAL Status=False
gnn_energy_Input64Zseg_output3D_zdc_64Fe=np. array([ 10.,  11.,  12.,  13.,  14.,  16.,  17.,  19.,  21.,  24.,  26.,
        29.,  32.,  35.,  39.,  43.,  47.,  52.,  57.,  63.,  70.,  77.,
        85.,  93., 103., 114., 125., 138., 152., 168., 185., 204., 225.,
       248., 274.])
gnn_phi_res_fit_Input64Zseg_output3D_zdc_64Fe=np. array([108.703249,  98.202715,  90.479059,  86.871533,  86.017905,
        81.101915,  77.404621,  71.527623,  68.538741,  65.895301,
        63.010289,  54.233386,  53.107992,  52.745853,  50.922052,
        47.958835,  48.982467,  42.819087,  42.817568,  41.003805,
        39.418247,  37.780723,  33.620471,  33.863215,  32.11117 ,
        30.793427,  30.856167,  28.776615,  29.274958,  28.067027,
        26.49414 ,  27.430675,  25.156428,  26.014058,  25.492691])


#Ryan's numbers
RM_energy=np.array([10.,  11.,  12.,  13.,  14.,  16.,  17.,  19.,  21.,  24.,  26.,
        29.,  32.,  35.,  39.,  43.,  47.,  52.,  57.,  63.,  70.,  77.,
        85.,  93., 103., 114., 125., 138., 152., 168., 185., 204., 225.,
       248., 274., 302.])

#mrad
RM_th_res=np.array([0.20402 , 0.196213, 0.189261, 0.181842, 0.176967, 0.159359,
       0.15339 , 0.141767, 0.132393, 0.131955, 0.12275 , 0.114508,
       0.107211, 0.102532, 0.098484, 0.091446, 0.089304, 0.085634,
       0.081101, 0.076227, 0.07267 , 0.069081, 0.064609, 0.064571,
       0.06146 , 0.058149, 0.054894, 0.053096, 0.050096, 0.047076,
       0.047515, 0.045223, 0.043249, 0.040519, 0.041694, 0.038457])
plt.errorbar(RM_energy, RM_th_res*z_front_face,
            color='r', label="staggered, GNN", marker='s', ls='')

fit_res_stoch_only(RM_energy, RM_th_res*z_front_face, None)


yr_req(color='tab:brown', ls='--')

x=np.linspace(10, 300,100)
y=1/np.sqrt(x)*z_front_face
plt.errorbar(x,y, label='YR stretch goal: $\\frac{1\,\\rm mrad}{\\sqrt{E}}$', ls=':', marker='', color='r')


legend = plt.legend(frameon=False, facecolor='white', edgecolor='white', loc='upper right', fontsize=18)
legend.set_zorder(5)
#axs.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator(10))

# frame = legend.get_frame()
# frame.set_facecolor('white')
# frame.set_edgecolor('white')
plt.ylim(0, 20)
write_geom("Fe",15, 70)

theta_axis()

#plt.gca().set_xscale('log')
plt.gca().set_title("ZDC neutron simulation")

#frame.set_zorder(20)

output_pdf = PdfPages('/home/ryan/ml_analysis/zdc_paper_plots/zdc_position_resolution.pdf')
output_pdf.savefig(fig)
output_pdf.close()
# plt.show()
# Out:
# sigma(dr)= 27.23962702720938
# sigma(dr)= 26.281753945421478
# sigma(dr)= 25.24298678506457
# sigma(dr)= 22.542013814543402
# sigma(dr)= 23.925927154192102
# sigma(dr)= 24.500565903762414
# sigma(dr)= 24.852997437590226
# sigma(dr)= 22.009140696757086
# sigma(dr)= 25.754613493878843
# sigma(dr)= 20.794354170928365
# sigma(dr)= 22.09540143313564
# sigma(dr)= 15.807711429989281
# sigma(dr)= 18.285605410148154
# sigma(dr)= 14.839572265524943
# Energies=[11.374977633404878, 14.503045598687372, 18.49131826157661, 23.576348065944416, 30.059738319552796, 38.32603189063052, 48.86551921598633, 62.30331840932584, 79.43645226927092, 101.28112129872721, 129.13297659311044, 164.64396750321498, 209.92032206160707, 267.64747158797866] #GeV
# sigma_thetas=[0.43065176732627464, 0.4157405765478967, 0.3601281842248923, 0.31850201248736176, 0.2906345416897446, 0.2632766360035075, 0.24318695322060754, 0.206796507977454, 0.1830461072263809, 0.15603368146991708, 0.14280459944311447, 0.12737255930387584, 0.11397711570838613, 0.10891584640550113] #mrad
# dsigma_thetas=[0.010724353315254459, 0.010860655016231806, 0.00895325160742006, 0.009472767129169812, 0.007607087217170311, 0.009397980448002318, 0.007560042745847119, 0.0063329999549731645, 0.0027883715647675305, 0.0032964969412804662, 0.0029327644373919005, 0.001826406682091038, 0.0035183135884327052, 0.00383241309477103] #mrad
# sigma(dr)= 27.588412871511782
# sigma(dr)= 29.449887313952665
# sigma(dr)= 28.78122072764337
# sigma(dr)= 25.455037059267678
# sigma(dr)= 28.822444922460562
# sigma(dr)= 25.81323945094687
# sigma(dr)= 24.6898470806421
# sigma(dr)= 23.32338473896025
# sigma(dr)= 24.80607185440096
# sigma(dr)= 23.712054939185045
# sigma(dr)= 21.20380233324094
# sigma(dr)= 21.67855480793858
# sigma(dr)= 19.401576206689896
# sigma(dr)= 16.75027378547745
# Energies=[11.374977633404878, 14.503045598687372, 18.49131826157661, 23.576348065944416, 30.059738319552796, 38.32603189063052, 48.86551921598633, 62.30331840932584, 79.43645226927092, 101.28112129872721, 129.13297659311044, 164.64396750321498, 209.92032206160707, 267.64747158797866] #GeV
# sigma_thetas=[0.4428851942583087, 0.4336550308753405, 0.4007352311228381, 0.33316822798639945, 0.28865214020151986, 0.25170525706772434, 0.1998514658884639, 0.1638092619473111, 0.13636693965670924, 0.1123267884071314, 0.09559705687402864, 0.08204016813517752, 0.0684311349557453, 0.05064005844251453] #mrad
# dsigma_thetas=[0.012867195754530452, 0.014270230411958212, 0.01931485826401233, 0.01545873469260756, 0.019125545236071892, 0.021610018514455598, 0.011061317164735551, 0.010217498937745591, 0.007568711197670819, 0.00507154854406823, 0.0038990255506476243, 0.0022770457101707587, 0.0021966900669093833, 0.0006784040093946408] #mrad
# sigma(dr)= 31.45568067950523
# sigma(dr)= 32.77124926944587
# sigma(dr)= 30.310608031736184
# sigma(dr)= 26.87802412400348
# sigma(dr)= 30.401982814683006
# sigma(dr)= 24.79452572879058
# sigma(dr)= 23.313706909931405
# sigma(dr)= 22.057383674143328
# sigma(dr)= 24.906903648853426
# sigma(dr)= 23.448249484002744
# sigma(dr)= 20.586502810398187
# sigma(dr)= 21.06899893252771
# sigma(dr)= 18.47321954063063
# sigma(dr)= 15.950253601957876
# Energies=[11.374977633404878, 14.503045598687372, 18.49131826157661, 23.576348065944416, 30.059738319552796, 38.32603189063052, 48.86551921598633, 62.30331840932584, 79.43645226927092, 101.28112129872721, 129.13297659311044, 164.64396750321498, 209.92032206160707, 267.64747158797866] #GeV
# sigma_thetas=[0.35496473852944216, 0.3203222383819482, 0.30746963895592605, 0.24234518086416776, 0.21286028239032798, 0.18009629430633028, 0.15147256612053978, 0.12908250708700572, 0.10474602354754249, 0.08858723698662596, 0.07595815703439468, 0.06449808764854349, 0.06132048719481145, 0.05218530792285662] #mrad
# dsigma_thetas=[0.017728442449878496, 0.015827682560350942, 0.012413530856614072, 0.010970357043496857, 0.011498277453837477, 0.007618363984442656, 0.006364650087005522, 0.004959102769801004, 0.0040886124301948625, 0.0032797327282542647, 0.002340503821686277, 0.0011387092687462905, 0.0014111859523776504, 0.0011364984899602515] #mrad
# fit: $0.63/\sqrt{E}$ mrad

# %%
def fit_res(bcs, sigmas,dsigmas, mus, dmus):
    P0=[10, 1]
    fnc = lambda E, b,c: np.hypot(b/np.sqrt(E),c)
    P, cov =curve_fit(fnc,bcs, sigmas, p0=P0, sigma=dsigmas)
    x=np.linspace(10, 300,100)
    label=f'fit: ${P[0]/z_front_face:.2f}/\\sqrt{{E}} \\oplus {P[1]/z_front_face:.3f}$ mrad'
    plt.errorbar(x, fnc(x,*P), label=label, color='green', marker='',ls=':')

ret=res_plot(df_h4_gamma_Fe, label="staggered, baseline", rw="", w0_params=(5.4,0.37,0.0), fit=False, color='tab:orange', fillstyle='none', shift=0.007*3)
a=fit_res(*ret)
ret=res_plot(df_h4_gamma_Fe, label="staggered, HEXPLIT", rw="_rw", w0_params=(6.0,-0.46,0.099), fit=False, color='tab:orange', fillstyle='none', shift=0.007*3)
a=fit_res(*ret)
legend = plt.legend(frameon=False, facecolor='white', edgecolor='white', loc='upper right', fontsize=18)
legend.set_zorder(5)

E=np.linspace(10, 274)
plt.plot(E, z_front_face*1000*.135/np.sqrt(E*(275-E)), ls='-')
print(z_front_face*1000*.135/np.sqrt(E*(275-E)))

plt.ylim(0, 5)
write_geom("Fe",0.2, x=12)
theta_axis()

plt.gca().set_xscale('log')
plt.gca().set_title("ZDC photon simulation")

# plt.savefig("images/position_resolution_zdc_design_paper_photon.pdf")
plt.show()
# Out:
# sigma(dr)= 3.008830150317516
# sigma(dr)= 2.44583103778338
# sigma(dr)= 2.329555085839653
# sigma(dr)= 1.7947271239653317
# sigma(dr)= 1.6203884927261967
# sigma(dr)= 1.3939388536740895
# sigma(dr)= 1.2544885384470852
# sigma(dr)= 1.1383562771087001
# sigma(dr)= 0.9859918500958245
# sigma(dr)= 0.9042821559355619
# sigma(dr)= 0.8160507598423529
# sigma(dr)= 0.773453942230831
# sigma(dr)= 0.7179567917543678
# sigma(dr)= 0.6690881713535319
# Energies=[11.374977633404878, 14.503045598687372, 18.49131826157661, 23.576348065944416, 30.059738319552796, 38.32603189063052, 48.86551921598633, 62.30331840932584, 79.43645226927092, 101.28112129872721, 129.13297659311044, 164.64396750321498, 209.92032206160707, 267.64747158797866] #GeV
# sigma_thetas=[0.05959771796801093, 0.05357624282002984, 0.049321772664155314, 0.044131405736281, 0.040607479775955954, 0.035770500688314964, 0.033268260821382276, 0.030636395380585008, 0.027079882628326928, 0.025243335891544014, 0.02301238162279571, 0.02200039426929274, 0.020698674434083107, 0.01902849472678694] #mrad
# dsigma_thetas=[0.0008349386041746898, 0.0005511664050685533, 0.0005586273663060493, 0.0006328146786386905, 0.0006810044462334658, 0.0006231403408087092, 0.00037055465339613406, 0.00041015145161149184, 0.0002695643744658911, 0.000505029571800639, 0.0003329643442104513, 0.00023693344796889079, 0.00031656059357644377, 0.00043376072896045514] #mrad
# sigma(dr)= 3.1172677244284737
# sigma(dr)= 2.541848930758162
# sigma(dr)= 2.420419372294425
# sigma(dr)= 1.899177254173999
# sigma(dr)= 1.7315664579493806
# sigma(dr)= 1.5630722938510666
# sigma(dr)= 1.4081213028051327
# sigma(dr)= 1.2624931348686728
# sigma(dr)= 1.1581018913042567
# sigma(dr)= 1.0713207125444815
# sigma(dr)= 0.9964884662213542
# sigma(dr)= 0.9603182850939883
# sigma(dr)= 0.9267124516318108
# sigma(dr)= 0.8988583371215395
# Energies=[11.374977633404878, 14.503045598687372, 18.49131826157661, 23.576348065944416, 30.059738319552796, 38.32603189063052, 48.86551921598633, 62.30331840932584, 79.43645226927092, 101.28112129872721, 129.13297659311044, 164.64396750321498, 209.92032206160707, 267.64747158797866] #GeV
# sigma_thetas=[0.060408827597848616, 0.055986490424680506, 0.051705065995097575, 0.04821892944046178, 0.04397032328190327, 0.04139776860247579, 0.03779074425979389, 0.0354692771985818, 0.03277006467972022, 0.031284212060721094, 0.029284851570258084, 0.028505116839763624, 0.028073674234529684, 0.027297448255221207] #mrad
# dsigma_thetas=[0.0009063373586677044, 0.0005180858251879582, 0.0009286141208427182, 0.0009034964074572701, 0.0009296632113851883, 0.0008183617040185763, 0.00044984026248431696, 0.0006945292031550995, 0.00035902003888781955, 0.0004429012640051731, 0.0006565543915725791, 0.0008175259754681859, 0.0007551630245212155, 0.0007825851786245679] #mrad
# [ 93.88449146  76.46568368  66.50162443  59.89817298  55.14499619
#   51.53843374  48.70090439  46.40945965  44.52301181  42.94746727
#   41.61744928  40.48602592  39.51860713  38.68915029  37.97771069
#   37.36880968  36.8503185   36.41267794  36.0483432   35.75138395
#   35.51719397  35.34228055  35.22411367  35.1610215   35.15212361
#   35.19729651  35.29716887  35.45314599  35.66746553  35.94328878
#   36.28483499  36.69757048  37.18846994  37.76637614  38.44249769
#   39.23110529  40.15052154  41.224557    42.48464591  43.97311849
#   45.74839526  47.89359138  50.53152873  53.85267174  58.17157417
#   64.05409305  72.65147584  86.80880589 116.67552485 291.97220771]

# %%
np.exp(np.linspace(np.log(10), np.log(300), 15))
# Out:
# array([ 10.        ,  12.74995527,  16.25613593,  20.72650059,
#         26.42619554,  33.6932811 ,  42.95878268,  54.77225575,
#         69.83438107,  89.03852347, 113.52371913, 144.74223406,
#        184.54570095, 235.29494318, 300.        ])

# %%
import matplotlib.patches as patches;
from matplotlib.patches import Ellipse
def dist_plot(dist_bins=[0,1,2,3,4,5]):
    
    colors="tab:blue tab:orange tab:green tab:red 0.65".split()
    for i in range(len(dist_bins)-1):
        a=max(dist_bins[i:i+2])/10
        plt.gca().add_patch(Ellipse((0, 0), a*z_front_face*2, a*z_front_face*2,
                                     color=colors[i], ec='white' if a!=0 else 'k', linewidth=0.5, 
                                        zorder=300-a, hatch="////" if i==4 else None))
    
        
        #plt.plot([-30+a, -30+a, 30-a, 30-a, -30+a], 
        #         [-30+a, 30-a, 30-a, -30+a, -30+a], color='white', lw=0.5)
    plt.xlim(-37, 37)
    plt.ylim(-37, 37)
    plt.gca().invert_xaxis()
    plt.gca().set_aspect(1)
    plt.xlabel("x [cm]")
    plt.ylabel("y [cm]")
    plt.plot([-30, -30, 30, 30, -30], [-30, 30, 30, -30, -30], ls='-', color='k', linewidth=2)
dist_plot()

# %%
alt_residual=True

dfs=[df_h1, df_h4, df_h4]
labels='unstaggered', 'staggered, baseline', 'staggered, HEXPLIT'
colors=['tab:blue', 'tab:orange', 'tab:green']
fs=['none', 'none', 'full']
ls=[':','--','-']
rws=["","", "_rw"]

# dfs=[df_h1, df_h3, df_h4, df_h3, df_h4]
# labels='unstaggered', 'H3, baseline', 'H4, baseline', 'H3, HEXPLIT', 'H4, HEXPLIT'
# colors=['k', 'tab:blue', 'tab:orange','tab:blue', 'tab:orange']
# fs=['none', 'none', 'none', 'full', 'full']
# ls=[':','--','--','-','-']
# rws=["","","", "_rw", "_rw"]

# dfs=[df_h4]
# labels='H4, HEXPLIT',
# colors=['tab:blue']
# fs=['full']
# ls=['-']
# rws=["_rw"]

use_mm=True

for i in range(len(dfs)):
    
    rw=rws[i]
    
    l=np.log(100/50)
    w0=5.0+0.65*l+0.31*l*l
    w0str=f'{int(w0*4)/4}'.replace('.', 'pt')
    #x=dfq[f'x_truth_face']
    dfq=dfs[i].query("theta_mrad<4 and abs(mc_pz-100)<10")
    if not alt_residual:
        dr=dfq[f'dr{rw}_w0_{w0str}']
    else:
        dx=dfq.eval(f'dx{rw}_w0_{w0str}/z_truth_w0_{w0str}*{z_front_face*1000}')
        dy=dfq.eval(f'dy{rw}_w0_{w0str}/z_truth_w0_{w0str}*{z_front_face*1000}')
        dr=(dx*dfq.eval("x_truth_face")+dy*dfq.eval("y_truth_face"))/dfq.eval("sqrt(x_truth_face**2+y_truth_face**2)")
    if use_mm:
        a=dr
    else:
        a=dr/z_front_face
    window=0.5*z_front_face if use_mm else 0.5
    y, x=np.histogram(a, bins=np.linspace(-window,window,30))
    dy=np.sqrt(y)
    bcs=(x[1:]+x[:-1])/2
    
    plt.errorbar(bcs, y/np.sum(y), dy/np.sum(y), label=labels[i], marker='o', ls ='',color=colors[i],
                fillstyle=fs[i])
    a_in_window=a[(a>=x[0])&(a<=x[-1])]
    p0=[10,np.mean(a_in_window), np.std(a_in_window)*.9]
    nsigma=2
    slc=np.abs(bcs-np.mean(a_in_window))<nsigma*np.std(a_in_window)
    fnc=gauss
    coeff, var_matrix = curve_fit(fnc, bcs[slc], y[slc]/np.sum(y), p0=p0,
                             sigma=dy[slc]/np.sum(y))
    x=np.linspace(-window,window, 100)
    plt.errorbar(x,fnc(x, *coeff), 
                       label=f"fit: $\\sigma={abs(coeff[2]):.3f}\\pm {np.sqrt(var_matrix[2][2]):.3f}$ mrad" \
                           if not use_mm else f"fit: $\\sigma={abs(coeff[2]):.1f}\\pm {np.sqrt(var_matrix[2][2]):.1f}$ mm", 
                color=colors[i], ls=ls[i])
    #return abs(coeff[2]),np.sqrt(var_matrix[2][2]),coeff[1], np.sqrt(var_matrix[1][1])
plt.legend(fontsize=16)
plt.title("ZDC simulation, 100 GeV neutrons")
if not use_mm:
    plt.xlabel('$\\theta$ residual [mrad]')
else:
    plt.xlabel('radial residual [mm]')
plt.ylabel("# of events (normalized)")
plt.ylim(0)

write_geom("Fe",0.150, -18)
# plt.savefig("images/theta_residuals.pdf")
print()
plt.show()

# %%
for k,(absorber,dataset) in enumerate(zip("Fe".split(), [dfs_AI['Fe'],])):
    if k==1:
        continue
    fig, axs=plt.subplots(2,2, figsize=(12,8), sharex='all', gridspec_kw=dict(height_ratios=(17,17), width_ratios=(4,2.5)))
    #bins=[300, 150, 100, 50, 25,0]
    bins=[0, 1,2,3,4]
    plt.sca(axs[0][0])
    colors="tab:blue tab:orange tab:green tab:red 0.65".split()
    for i in range(len(bins)-1):
        plt.sca(axs[0][0])
        fs="full" if i <=3 else "none"
        #bcs, _,_, mus, dmus= res_plot(dataset.query(f"sqrt(x_truth_face**2+y_truth_face**2)>=0 and dist_from_edge<{bins[i]} and dist_from_edge>{bins[i+1]}"), 
                           
        #        fit = False, nEnergyBins=10, shift=i*.007, fillstyle=fs, color=colors[i])
        bcs, _,_, mus, dmus= res_plot(dataset.query(f"theta_mrad>{bins[i]} and theta_mrad<{bins[i+1]}"),
                use_dr=False,
                fit = False, nEnergyBins=10, shift=i*.007, fillstyle=fs, color=colors[i])
        
        plt.sca(axs[1][0])
        plt.errorbar(np.array(bcs)*(1+i*.007), mus, dmus, marker='o', ls='', fillstyle=fs, color=colors[i])
        axs[0][1].errorbar([],[],[], ls='', marker='o', label=f" {bins[i]}$-${bins[i+1]} mrad", fillstyle=fs, color=colors[i])
    plt.sca(axs[0][0])
    yr_req('YR requirement: $\\frac{3\,\, mrad}{\\sqrt{E}}$', color='tab:brown', ls='--')
    axs[0][1].errorbar([], [], color='tab:brown', ls='--',
                      label='YR requirement:\n$3\,\, mrad/\sqrt{E}$')
    plt.ylim(0, 10)
    plt.ylabel("$\\sigma_r$ [mm]")
    
    plt.rcParams['legend.loc']='upper right'
    plt.rcParams['legend.fontsize']=18
    #axs[0][1].legend(title="distance from \nnearest edge:",loc='upper right', edgecolor='white', title_fontsize=18)
    axs[0][1].legend(title="$\\theta$ range:",loc='upper right', edgecolor='white', title_fontsize=18)
    ax2=theta_axis()
    ax2.tick_params(axis="y", labelsize=20)
    ax2.set_ylabel("$\\sigma_\\theta$ [mrad]", fontsize=20)
    plt.sca(axs[1][0])
    plt.ylim(-5, 5)
    plt.ylabel("$\mu_r-r_{\\rm truth}$ [mm]")
    plt.axhline(0, color='0.5', alpha=0.7, ls='--')
    plt.subplots_adjust(hspace=0)
    plt.xlabel("Energy [GeV]")
    ax2=theta_axis()
    ax2.tick_params(axis="y", labelsize=20)
    ax2.set_ylabel("$\\mu_\\theta-\\theta_{\\rm truth}$ [mrad]", fontsize=20)
    
    axs[0][1].axis('off')
    axs[1][1].axis('off')
    
    # These are in unitless percentages of the figure size. (0,0 is bottom left)
    #left, bottom, width, height = [0.65, 0.1, 0.29, 0.29]
    left, bottom, width, height = [0.67, 0.1, 0.27, 0.27]
    inset = fig.add_axes([left, bottom, width, height])
    inset.set_title(f"ZDC front face\n($z$={z_front_face} m)", fontsize=16)
    
    dist_plot([0,1,2,3,4])
    inset.set_ylabel("y [cm]", fontsize=16)
    inset.set_xlabel("x [cm]", fontsize=16)
    inset.tick_params(axis='both', which='major', labelsize=16, length=7)
    inset.tick_params(axis='both', which='minor', length=5)
    import matplotlib.ticker as ticker
    inset.xaxis.set_major_locator(ticker.MultipleLocator(20))
    inset.xaxis.set_minor_locator(ticker.MultipleLocator(5))
    for axis in ['top','bottom','left','right']:
        inset.spines[axis].set_linewidth(1.3)
    axs[1][0].set_xscale('log')
    fig.suptitle("ZDC neutron simulations, GNN reconstruction", fontsize=24)
    plt.sca(axs[0][0])
    write_geom(absorber, 1.0)
    axs[1][0].set_ylabel("$\mu_r-r_{\\rm truth}$ [mm]")
    output_pdf = PdfPages('/home/ryan/ml_analysis/zdc_paper_plots/zdc_position_resolution_edge.pdf')
    output_pdf.savefig(fig)
    output_pdf.close()
#     plt.savefig(f"images/edge_effects_layout2_{absorber}.pdf")
    plt.show()
# Out:
# sigma(dr)= 17.113250732421875
# sigma(dr)= 16.287954330444336
# sigma(dr)= 16.770647048950195
# sigma(dr)= 16.916736602783203
# sigma(dr)= 14.322941780090332
# sigma(dr)= 14.42172622680664
# sigma(dr)= 15.952364921569824
# sigma(dr)= 16.32135581970215
# sigma(dr)= 13.38826847076416
# Energies=[12.296164014805425, 17.94296588099375, 26.182964395957626, 38.20704052534353, 55.75296683864479, 81.35655807335203, 118.7181582766438, 173.23743086440467, 252.79374181804232] #GeV
# sigma_thetas=[0.23364667179151782, 0.17377972489091292, 0.14876033598588995, 0.12252032884294581, 0.10349067881296016, 0.09761749343864667, 0.08241752901975036, 0.08387961838304964, 0.06970935291341779] #mrad
# dsigma_thetas=[0.016554677259761393, 0.008062400492317134, 0.014324745312966574, 0.004393886576665212, 0.0042936189751675525, 0.0017440081677016785, 0.002042040935297366, 0.0014363575621011975, 0.002411340618607174] #mrad
# sigma(dr)= 13.751123428344727
# sigma(dr)= 12.569650650024414
# sigma(dr)= 11.55856704711914
# sigma(dr)= 11.062368392944336
# sigma(dr)= 11.27134895324707
# sigma(dr)= 11.560406684875488
# sigma(dr)= 10.797314643859863
# sigma(dr)= 10.414833068847656
# sigma(dr)= 10.354616165161133
# Energies=[12.296164014805425, 17.94296588099375, 26.182964395957626, 38.20704052534353, 55.75296683864479, 81.35655807335203, 118.7181582766438, 173.23743086440467, 252.79374181804232] #GeV
# sigma_thetas=[0.19780035415755434, 0.1574390344111257, 0.13333595622348218, 0.10840352466277013, 0.0856084665803776, 0.07369694518124915, 0.06136164448604465, 0.05335688243512868, 0.046790200536344674] #mrad
# dsigma_thetas=[0.002424389112708371, 0.0028468761850219525, 0.0019967969960726787, 0.0014073398142965222, 0.0011034330907526931, 0.0015853717361546966, 0.0008211781678593727, 0.0006481475734325, 0.0004183356989773776] #mrad
# sigma(dr)= 10.146809577941895
# sigma(dr)= 10.352888107299805
# sigma(dr)= 8.780659675598145
# sigma(dr)= 9.009072303771973
# sigma(dr)= 8.242875099182129
# sigma(dr)= 8.096502304077148
# sigma(dr)= 7.695314884185791
# sigma(dr)= 6.914576530456543
# sigma(dr)= 7.058846473693848
# Energies=[12.296164014805425, 17.94296588099375, 26.182964395957626, 38.20704052534353, 55.75296683864479, 81.35655807335203, 118.7181582766438, 173.23743086440467, 252.79374181804232] #GeV
# sigma_thetas=[0.198399340369769, 0.16553714096273608, 0.130776606919265, 0.10496843408085256, 0.08557986487037021, 0.06757448613932616, 0.05649493781342544, 0.04758286062795295, 0.04037436653851571] #mrad
# dsigma_thetas=[0.0035635381650608116, 0.002530516262204584, 0.0022832595029038307, 0.0014369616388039505, 0.0017703246562277785, 0.000707291901846712, 0.0005183135669711319, 0.0002427161797031589, 0.0006083137782767967] #mrad
# sigma(dr)= 10.192764282226562
# sigma(dr)= 9.19979190826416
# sigma(dr)= 8.700005531311035
# sigma(dr)= 8.45217227935791
# sigma(dr)= 7.835503578186035
# sigma(dr)= 8.114542961120605
# sigma(dr)= 7.777435779571533
# sigma(dr)= 7.523323059082031
# sigma(dr)= 7.554786682128906
# Energies=[12.296164014805425, 17.94296588099375, 26.182964395957626, 38.20704052534353, 55.75296683864479, 81.35655807335203, 118.7181582766438, 173.23743086440467, 252.79374181804232] #GeV
# sigma_thetas=[0.1990653337713476, 0.15360639143735358, 0.12905399695295422, 0.1042156726866374, 0.08365851136100379, 0.06874064787814717, 0.05491548212843686, 0.04586032634649347, 0.03961173496573672] #mrad
# dsigma_thetas=[0.003073893244922271, 0.002151827529728837, 0.0013556017109777733, 0.0019044869781781114, 0.0009080330418206163, 0.001043571942513606, 0.0007843964988794942, 0.0005835024600431879, 0.0006542500644128567] #mrad

# %% [markdown]
# # Energy resolutions

# %%
path_strawman="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_Fe_strawman_discrete/*.csv"
dfs=[]
for file in glob.glob(path_strawman):
    df_sm=pd.read_csv(file)
    #print("read file:", file)
    dfs.append(df_sm)
    #print("added file", file)
df_strawman=pd.concat(dfs)
print("Fe", len(df_strawman))
del dfs, df_sm


path_strawman="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_gamma_Fe_strawman_discrete_800MeV/*.csv"
dfs=[]
for file in glob.glob(path_strawman):
    df_sm=pd.read_csv(file)
    #print("read file:", file)
    dfs.append(df_sm)
    #print("added file", file)
df_gamma_strawman=pd.concat(dfs)
print("Fe", len(df_strawman))
del dfs, df_sm


path_strawman_Pb="/home/sebouh/staggered_tesselations/dd4hep/cache/large_scale/h4_Pb_strawman_discrete/*.csv"
dfs=[]
for file in glob.glob(path_strawman_Pb):
    df_sm=pd.read_csv(file)
    #print("read file:", file)
    dfs.append(df_sm)
    #print("added file", file)

df_strawman_Pb=pd.concat(dfs)
print("Pb", len(df_strawman_Pb))
del dfs, df_sm
# Out:
# Fe 315000
# Fe 315000
# Pb 500000

# %%
for df in df_strawman, df_strawman_Pb, df_gamma_strawman:
    df['dist_from_edge']=df.eval("(300-abs(y_truth))*(300-abs(y_truth)<300-abs(x_truth))+"\
                            +"(300-abs(x_truth))*(300-abs(y_truth)>=300-abs(x_truth))")
    df['theta_mrad']=df.eval(f"sqrt(x_truth**2+y_truth**2)/{z_front_face}")

# %%
#plt.hist(df_strawman_Pb['dist_from_edge'], bins=100)

# %%
#strawman and AI in one figure

#first step is make the bins be centered around the different discrete points
energies=np.array(sorted(list((set(np.round(df_strawman.E_truth*100)/100)))))
f=np.sqrt(energies[1]/energies[0])
energy_bins=np.concatenate([energies/f, [energies[-1]*f]])

energy_bins=energy_bins[energy_bins>20]

maxDist=3000
integrated=True

for abso in "Fe Pb".split()[:1]:
    fig, axs=plt.subplots(2,1, figsize=(10.5,10), sharex='all', gridspec_kw=dict(height_ratios=(7,4)))
        
    divide_by_mu=True
    
    sfs=[0.021, 1]
    labels=['"strawman"', "GNN"]
    colors="tab:blue tab:orange tab:green tab:red 0.65".split()
    if abso=="Fe":
        dfs=df_strawman, dfs_AI['Fe']
    if abso=="Pb":
        dfs=df_strawman_Pb, dfs_AI['Pb']
    for k in 0,1:
        #fig, axs=plt.subplots(2,2, figsize=(12,8), sharex='all', gridspec_kw=dict(height_ratios=(6,4), width_ratios=(4,1.5)))
        dist_bins=[0,4]
        
        #axs[0].errorbar([],[], label="distance from nearest edge:", color='white')
        for i in range(len(dist_bins)-1):
            fs="full" if i<=3 else "none"
            bcs=[]
            sigmas=[]
            dsigmas=[]
            mus=[]
            dmus=[]
            for j in range(len(energy_bins)-1):
                dfq=dfs[k].query(f"E_truth>{energy_bins[j]} and E_truth<{energy_bins[j+1]} and E_reco>0")
                dfq=dfq.query(f"theta_mrad>{dist_bins[i]} and theta_mrad<{dist_bins[i+1]}")
                
                bcs.append((energy_bins[j]+energy_bins[j+1])/2)
                Eshower=dfq['E_reco']/sfs[k]
                Etruth=dfq.E_truth
            
                
                sf=1
                if not divide_by_mu:
                    a=Eshower/Etruth/sf-1
                    #print(a)
                    a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                else :
                    a=Eshower/sf/Etruth
                    a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                #print(np.mean(a))
                sigma,dsigma,mu, dmu=res_calc(a, nsigma=2)
                sigmas.append(sigma)
                dsigmas.append(dsigma)
                mus.append(mu)
                dmus.append(dmu)
                #ymid=1
            method="strawman" if k==0 else "GNN"
            axs[0].errorbar(np.array(bcs)*(1-i*.007), np.array(sigmas)*100/(np.array(mus)), np.array(dsigmas)/(np.array(mus))*100, 
                     label=f"ZDC sim ({method} recon)", marker='o', ls='', color=colors[i], fillstyle="full" if k==1 else "none")
            axs[1].errorbar(np.array(bcs)*(1-i*.007), (np.array(mus)-1)*100, np.array(dmus)*100, 
                 label=f"ZDC sim", marker='o', ls='', color=colors[i],fillstyle="full" if k==1 else "none")
            print(f"Energies={list(bcs)}")
            print(f"energy_resolutions_{method}={list(np.array(sigmas)*100/(np.array(mus)))}")
            print(f"energy_dresolutions_{method}={list(np.array(dsigmas)/(np.array(mus))*100)}")
            print(f"energy_offsets_{method}={list((np.array(mus)-1)*100)}")
            print(f"energy_doffsets_{method}={list(np.array(dmus)*100)}")
            
            
            P0=[40,5]
            fnc = lambda E, a,b: np.sqrt(a**2/E+b**2)
            y=np.array(sigmas)
            dy=np.array(dsigmas)
            if divide_by_mu:
                y=y/np.array(mus)
                dy=dy/np.array(mus)
            bcs=np.array(bcs)
            slc=(bcs>15)&(bcs<250)
            P, cov = curve_fit(fnc,bcs[slc], y[slc], p0=P0, sigma=dy[slc])
            x=np.linspace(10, 300)
            axs[0].errorbar(x, fnc(x,*P)*100, ls=':' if k==0 else "--", color='tab:green', label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.0f}\%$")
            print(labels, abso, f"fit: ${abs(P[0])*100:.0f}\%/\\sqrt{{E}}\\oplus{abs(P[1])*100:.0f}\%$")
            #axs[0][-1].errorbar([], [], label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.1f}\%$", ls=':', color='tab:green')
        axs[0].set_ylim(0,18)
        
        if integrated:
            # C Adloff et al 2012 JINST 7 P09017
            if abso=="Fe":
                if k==0:
                    #uncorrected
                    CALICE='''E,s
                    10.092,0.175
                    15.055,0.148
                    20.018,0.131
                    24.982,0.118
                    35.074,0.098
                    40.037,0.095
                    45.000,0.090
                    49.963,0.084
                    60.055,0.076
                    79.908,0.064
                    18.033,0.133'''
                    
                else:
                    #corrected
                    CALICE='''E,s
                    9.952,0.152
                    14.856,0.121
                    18.029,0.112
                    19.904,0.101
                    24.952,0.089
                    34.904,0.076
                    39.952,0.072
                    45.000,0.069
                    49.904,0.064
                    59.856,0.060
                    79.976,0.055'''

                from io import StringIO
                df_CALICE=pd.read_csv(StringIO(CALICE))
                sfc="uncorrected" if k==0 else "software-compensated"
                axs[0].errorbar(df_CALICE.E, df_CALICE.s*100,marker='s', label=f"CALICE Fe/Sc data, $\pi^-$\n({sfc})", 
                                color='tab:orange', ls='', fillstyle="full" if k==1 else "none")
            if abso=="Pb" and k==0:
                #NIM A262 (1987) 229-242
                #energies, delta E/E sqrt(E). 
                #first half is bin centers.  second half is bottom of error bars
                ZEUS='''E,ssqrtE
                        20.185,43.292
                        28.034,45.223
                        33.889,46.135
                        39.744,46.039
                        51.579,42.318
                        59.303,43.996
                        67.152,42.650
                        75.000,44.454
                        20.185,42.284
                        28.034,44.340
                        33.889,45.253
                        39.744,45.157
                        51.579,41.436
                        59.428,42.988
                        67.276,41.642
                        75.125,43.447'''
                from io import StringIO
                df_ZEUS=pd.read_csv(StringIO(ZEUS))
                Es=df_ZEUS.E[0:len(df_ZEUS)//2]
                ss=df_ZEUS.ssqrtE[0:len(df_ZEUS)//2]/np.sqrt(Es)
                dss=np.abs(np.array(df_ZEUS.ssqrtE[len(df_ZEUS)//2:])-np.array(df_ZEUS.ssqrtE[0:len(df_ZEUS)//2]))/np.sqrt(Es)
                print("dss", dss)
                axs[0].errorbar(Es, ss,dss,
                                   marker='s', label="ZEUS Pb/Sc data", color='tab:orange', ls='', fillstyle='none')

        
        x=np.linspace(10, 275, 100)
        
        axs[1].set_xlabel("$E_{\\rm truth}$ [GeV]")
        axs[1].set_ylim(-40, 15)
        if not divide_by_mu:
            axs[0].set_ylabel("$\\sigma[E_{\\rm reco}/E_{\\rm truth}]$ [%]", fontsize=20)
        else:
            #axs[0].set_ylabel("$\\sigma[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]/\\mu[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]$ [%]", fontsize=20)
            axs[0].set_ylabel("$\\sigma[E_{\\rm reco}]/\\mu[E_{\\rm reco}]$ [%]", fontsize=20)
        
        axs[1].set_ylabel("$\\mu[E_{\\rm reco}]/E_{\\rm truth} -1$ [%]", fontsize=20)
        
        plt.subplots_adjust(hspace=0)
        
        axs[0].set_title(f'ZDC neutron simulations,\nenergy reconstruction', fontsize=24)
        axs[0].set_xscale("log")
        if k==0:
            #dummy to ensure that the legend looks right
            axs[0].errorbar([],[],[], color='white', label=" ")
        
    axs[1].axhline(0, color='0.5', alpha=0.7, ls='--')
    axs[0].errorbar(x, np.hypot(50/np.sqrt(x), 5), marker='', ls='--', lw=2, label='YR requirement:\n$50\%/\\sqrt{E}\\oplus 5\%$', color='tab:brown')
    if integrated:
        axs[0].legend(fontsize=16, ncol=2, framealpha=0)
    plt.sca(axs[0])
    plt.xlim(19, 300)
    write_geom(abso, 1, x=22)
    #plt.tight_layout()
#     plt.savefig(f"images/strawman_vs_AI_{abso}_integrated.pdf")
    output_pdf = PdfPages('/home/ryan/ml_analysis/zdc_paper_plots/zdc_energy_resolution.pdf')
    output_pdf.savefig(fig)
    output_pdf.close()
    
    plt.show()
# Out:
# Energies=[21.475867008531132, 23.85995526436274, 26.244043520194353, 29.10018125068062, 31.956318981166888, 35.29404253933114, 39.108583748661715, 42.923124957992286, 47.214483818489185, 51.9826603301524, 57.22765449298194, 63.426283958144126, 70.10173107447264, 77.25399584196745, 84.87831008411695, 93.45625962859907, 103.46943030309183, 113.95941862875091, 125.40304225674262, 138.27711883823332, 152.58164837322298, 168.3166308617116, 185.48206630369918, 204.55477235035204, 225.5347490016702, 248.89881390882, 274.6469670718013, 302.34038427778796]
# energy_resolutions_strawman=[12.28420133782348, 11.154520973136608, 11.068383348902689, 10.2532427483523, 9.823864024391616, 9.653671870051339, 8.886524109284059, 8.439902784125794, 7.91859739720874, 7.7230774642322935, 7.377551731590587, 7.234007849775285, 6.653443910500788, 6.56855906855992, 6.334907182601748, 6.285634848396214, 5.973905949004193, 5.635622327337112, 5.350248544166724, 5.095379201727766, 4.889123408531409, 4.674133956223437, 4.366409255358384, 4.219605508605078, 4.123369226098301, 4.262857167702018, 4.097815959349774, 4.610662373366166]
# energy_dresolutions_strawman=[0.21879399807875458, 0.1912806232742319, 0.24536690372038936, 0.1990275368856321, 0.16299237495493063, 0.19975759930587023, 0.13669146070697916, 0.13860845358352264, 0.15102523213064006, 0.166309394882589, 0.1725838582981493, 0.18989192044129866, 0.12414917483278695, 0.15965819297126624, 0.13715525094380115, 0.12648805924279583, 0.09515103469693034, 0.08298555623445102, 0.1175032442798059, 0.1142132563042659, 0.0770335187145568, 0.14767289498765956, 0.16512052901431518, 0.1727128063684152, 0.14557938813286286, 0.21521821939506852, 0.205132760071826, 0.31260438859160744]
# energy_offsets_strawman=[-26.957767751336704, -26.017543970758894, -25.33569632929291, -24.24458197992535, -23.694580297878776, -22.937439005297932, -22.064959438878663, -21.591041001508003, -21.01088723137494, -20.47015034346171, -19.915830080229966, -19.222999081796168, -18.83432808066665, -18.225906846859775, -17.950181404544207, -17.51194349775298, -16.997563305942354, -16.627090437387714, -16.38224609669764, -16.03717577257622, -15.758286921028631, -15.405593944899875, -15.437425849620535, -15.448186798810248, -15.698247465555582, -15.949058926729542, -16.25714627382959, -16.925922031140395]
# energy_doffsets_strawman=[0.17218713440681896, 0.15408555207857821, 0.20240714057254477, 0.16954173737439315, 0.12683321218772212, 0.15537844517943397, 0.11171064952927455, 0.10814319900973236, 0.1208876323370828, 0.13166697133162245, 0.14182756151710355, 0.1497385373085755, 0.10503814434930084, 0.1382994684869116, 0.12216541346828466, 0.11051240829725063, 0.0837601953767615, 0.07225684945737479, 0.10823104999338601, 0.10736336464132996, 0.07083108596646034, 0.14366955349130087, 0.16490637014957002, 0.17522924354749767, 0.15269957655029215, 0.21725077218865116, 0.1947448677592886, 0.29602261947923353]
# ['"strawman"', 'GNN'] Fe fit: $54\%/\sqrt{E}\oplus2\%$
# Energies=[21.475867008531132, 23.85995526436274, 26.244043520194353, 29.10018125068062, 31.956318981166888, 35.29404253933114, 39.108583748661715, 42.923124957992286, 47.214483818489185, 51.9826603301524, 57.22765449298194, 63.426283958144126, 70.10173107447264, 77.25399584196745, 84.87831008411695, 93.45625962859907, 103.46943030309183, 113.95941862875091, 125.40304225674262, 138.27711883823332, 152.58164837322298, 168.3166308617116, 185.48206630369918, 204.55477235035204, 225.5347490016702, 248.89881390882, 274.6469670718013, 302.34038427778796]
# energy_resolutions_GNN=[6.442215447722678, 6.3005005162549175, 5.961812733424048, 5.591324431251677, 5.395122876886378, 5.077857074885461, 4.832794045640568, 4.6821224130749695, 4.434947404776325, 4.427265492860963, 4.11035877380283, 4.066685962820162, 3.828586349901831, 3.726337149680445, 3.5094546246491047, 3.336310216771343, 3.170302057589442, 3.1335467113685858, 3.034543102610744, 2.9513967907863643, 2.8388872513642953, 2.7334832411198824, 2.630133646189506, 2.4904190194441225, 2.492647434086489, 2.2920466778346165, 2.2319008452156583, 2.052951735758644]
# energy_dresolutions_GNN=[0.08947976828228976, 0.07621840205046704, 0.07689390783628608, 0.06170494193431159, 0.04592346819467753, 0.06897821794683599, 0.06462037871815676, 0.07892335474708206, 0.041546620149057314, 0.0724637466291881, 0.04735767697363184, 0.04979715726072369, 0.060810132788301774, 0.052919120395900285, 0.06769769310556575, 0.034500630380587, 0.052674685519488035, 0.030919693374149175, 0.02820344323639947, 0.036736406662654195, 0.05825608389067149, 0.04216661900952317, 0.05767387375375704, 0.05993680643910414, 0.08114578888200574, 0.09501669067855509, 0.08252152910434317, 0.09353185411972513]
# energy_offsets_GNN=[-0.15741846765728873, 0.023639804195285663, 0.012314900407783824, -0.11117277329045772, 0.060977355304459024, -0.006567672100721289, 0.17697290091380768, 0.056357357485903314, 0.14985755416758728, 0.021718745193188838, -0.12133436206379633, 0.09267527173337786, 0.06466024053084496, 0.011682329766937727, 0.029746106513095505, 0.0672633193615324, 0.11866799693902585, -0.0032802403724718765, 0.03930858641822965, 0.12065771227405264, 0.10345697790892228, 0.10531571221890079, 0.17334774155648436, 0.13827980166252196, 0.05917764237486356, -0.014913957364071084, -0.30434464526708505, -0.6336852490701594]
# energy_doffsets_GNN=[0.09819714703238336, 0.08274446166088925, 0.07960106666059243, 0.061333156501413376, 0.045652179061815026, 0.06877546563049132, 0.06329793702440928, 0.0800147099131061, 0.04204393670937173, 0.0747025596826889, 0.0506593509004745, 0.052483845656620925, 0.06631174358765687, 0.06004873808625879, 0.06800557015117853, 0.03845387487876035, 0.0587055536557773, 0.0346098598095942, 0.030343381366037207, 0.04241463200231938, 0.06485834567707127, 0.04675934561220417, 0.06393737953346461, 0.06734847531204972, 0.09186856633465201, 0.10724069966911581, 0.09943102953935305, 0.10623710209613046]
# ['"strawman"', 'GNN'] Fe fit: $29\%/\sqrt{E}\oplus2\%$

# %%
# strawman and AI in one figure for edge effects

#first step is make the bins be centered around the different discrete points
energies=np.array(sorted(list((set(np.round(df_strawman.E_truth*100)/100)))))
f=np.sqrt(energies[1]/energies[0])
energy_bins=np.concatenate([energies/f, [energies[-1]*f]])

maxDist=3000


for integrated in False,:
    for abso in "Fe".split():
        if not integrated:
            fig, axs=plt.subplots(2,3, figsize=(22,8.0), sharex='all', gridspec_kw=dict(height_ratios=(6,3), width_ratios=(4.75,4.75,1.8)))
            
        divide_by_mu=True
        
        sfs=[0.021, 1]
        labels=['"strawman"', "GNN"]
        colors="tab:blue tab:orange tab:green tab:red 0.65".split()
        if abso=="Fe":
            dfs=df_strawman, dfs_AI['Fe']
        if abso=="Pb":
            dfs=df_strawman_Pb, dfs_AI['Pb']
        for k in 0,1:
            #fig, axs=plt.subplots(2,2, figsize=(12,8), sharex='all', gridspec_kw=dict(height_ratios=(6,4), width_ratios=(4,1.5)))
            if integrated:
                dist_bins=[0,4]
            else:
                dist_bins=[0, 1,2,3,4]
            #axs[0].errorbar([],[], label="distance from nearest edge:", color='white')
            for i in range(len(dist_bins)-1):
                fs="full" if i<=3 else "none"
                bcs=[]
                sigmas=[]
                dsigmas=[]
                mus=[]
                dmus=[]
                for j in range(len(energy_bins)-1):
                    dfq=dfs[k].query(f"E_truth>{energy_bins[j]} and E_truth<{energy_bins[j+1]} and E_reco>0")
                    dfq=dfq.query(f"theta_mrad>{dist_bins[i]} and theta_mrad<{dist_bins[i+1]}")
                    
                    bcs.append((energy_bins[j]+energy_bins[j+1])/2)
                    Eshower=dfq['E_reco']/sfs[k]
                    Etruth=dfq.E_truth
                
                    
                    sf=1
                    if not divide_by_mu:
                        a=Eshower/Etruth/sf-1
                        #print(a)
                        a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                    else :
                        a=Eshower/sf/Etruth
                        a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                    #print(np.mean(a))
                    sigma,dsigma,mu, dmu=res_calc(a, nsigma=2)
                    sigmas.append(sigma)
                    dsigmas.append(dsigma)
                    mus.append(mu)
                    dmus.append(dmu)
                    #ymid=1
                if divide_by_mu:
                    axs[0][k].errorbar(np.array(bcs)*(1-i*.007), np.array(sigmas)*100/(np.array(mus)), np.array(dsigmas)/(np.array(mus))*100, 
                             label=f"ZDC sim ({abso}/Sc)", marker='o', ls='', fillstyle=fs,color=colors[i])
                    axs[1][k].errorbar(np.array(bcs)*(1-i*.007), (np.array(mus)-1)*100, np.array(dmus)*100, 
                         label=f"ZDC sim", marker='o', ls='', fillstyle=fs, color=colors[i])
                else:
                    axs[0][k].errorbar(np.array(bcs)*(1-i*.007), np.array(sigmas)*100, np.array(dsigmas)*100, 
                             label=f"ZDC sim ({abso}/Sc)", marker='o', ls='', fillstyle=fs,color=colors[i])
                    axs[1][k].errorbar(np.array(bcs)*(1-i*.007), np.array(mus)*100, np.array(dmus)*100, 
                         label=f"ZDC sim", marker='o', ls='', fillstyle=fs, color=colors[i])
                if k==0 and not integrated:
                    axs[0][-1].errorbar([],[],[],  label=f" {dist_bins[i]}$-${dist_bins[i+1]} mrad", marker='o', ls='', fillstyle=fs, color=colors[i])
                
                if integrated:
                    P0=[40,5]
                    fnc = lambda E, a,b: np.sqrt(a**2/E+b**2)
                    y=np.array(sigmas)
                    dy=np.array(dsigmas)
                    if divide_by_mu:
                        y=y/np.array(mus)
                        dy=dy/np.array(mus)
                    bcs=np.array(bcs)
                    slc=(bcs>15)&(bcs<200)
                    P, cov = curve_fit(fnc,bcs[slc], y[slc], p0=P0, sigma=dy[slc])
                    x=np.linspace(10, 300)
                    axs[0][k].errorbar(x, fnc(x,*P)*100, ls=':', color='tab:green', label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.0f}\%$")
                    print(labels[k], abso, f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.0f}\%$")
                    #axs[0][-1].errorbar([], [], label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.1f}\%$", ls=':', color='tab:green')
            axs[0][k].set_ylim(0,17)

            
            x=np.linspace(10, 275, 100)
            axs[0][k].errorbar(x, np.hypot(50/np.sqrt(x), 5), marker='', ls='--', lw=2, label='YR requirement:\n$50\%/\\sqrt{E}\\oplus 5\%$', color='tab:brown')
            if k==0 and not integrated:
                axs[0][-1].errorbar([],[], marker='', ls='--', lw=2, label='YR requirement:\n$50\%/\\sqrt{E}\\oplus 5\%$', color='tab:brown')
                axs[0][-1].legend(fontsize=18, ncol=1, title="$\\theta$ range:", title_fontsize=20)
            
            axs[1][k].set_xlabel("$E_{\\rm truth}$ [GeV]")
            axs[1][k].set_ylim(-35, 10)
            if not divide_by_mu:
                axs[0][k].set_ylabel("$\\sigma[E_{\\rm reco}/E_{\\rm truth}]$ [%]", fontsize=20)
            else:
                #axs[0][k].set_ylabel("$\\sigma[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]/\\mu[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]$ [%]", fontsize=20)
                axs[0][k].set_ylabel("$\\sigma[E_{\\rm reco}]/\\mu[E_{\\rm reco}]$ [%]", fontsize=20)
            
            axs[1][k].set_ylabel("$\\mu[E_{\\rm reco}]/E_{\\rm truth} -1$ [%]", fontsize=20)
            
            plt.subplots_adjust(hspace=0)
            axs[1][k].axhline(0, color='0.5', alpha=0.7, ls='--')
            axs[0][k].set_title(f'ZDC neutron simulations,\n{labels[k]} energy reconstruction', fontsize=24)
            axs[0][k].set_xscale("log")
            axs[0][k].set_xlim(20, 300)
            if integrated:
                axs[0][k].legend(fontsize=16, ncol=1, loc='upper right')
        if not integrated:
            axs[0][-1].axis('off')
            axs[1][-1].axis('off')
        
        # These are in unitless percentages of the figure size. (0,0 is bottom left)
        left, bottom, width, height = [0.71, 0.1, 0.27, 0.27]
        if not integrated:
            inset = fig.add_axes([left, bottom, width, height])
            inset.set_title(f"ZDC front face\n($z$={z_front_face} m)", fontsize=16)
            
            dist_plot(dist_bins=[0,1,2,3,4])
            inset.set_ylabel("y [cm]", fontsize=16)
            inset.set_xlabel("x [cm]", fontsize=16)
            inset.tick_params(axis='both', which='major', labelsize=16, length=7)
            inset.tick_params(axis='both', which='minor', length=5)
            import matplotlib.ticker as ticker
            inset.xaxis.set_major_locator(ticker.MultipleLocator(20))
            inset.xaxis.set_minor_locator(ticker.MultipleLocator(5))
            for axis in ['top','bottom','left','right']:
                inset.spines[axis].set_linewidth(1.3)
        plt.sca(axs[0][0])
        write_geom(abso, 1, x=22)
        #plt.sca(axs[0][1])
        #write_geom(abso, 1, x=22)
        #plt.tight_layout()
#         if not integrated:
#             plt.savefig(f"images/strawman_vs_AI_{abso}_edge.pdf")
#         else:
#             plt.savefig(f"images/strawman_vs_AI_{abso}_integrated.pdf")
        output_pdf = PdfPages('/home/ryan/ml_analysis/zdc_paper_plots/zdc_energy_resolution_edge.pdf')
        output_pdf.savefig(fig)
        output_pdf.close()
        
        plt.show()

# %%
#strawman and AI in one figure

#first step is make the bins be centered around the different discrete points
energies=np.array(sorted(list((set(np.round(df_strawman.E_truth*100)/100)))))
f=np.sqrt(energies[1]/energies[0])
energy_bins=np.concatenate([energies/f, [energies[-1]*f]])

energy_bins=energy_bins[energy_bins>20]

maxDist=3000


for abso in "Fe".split():
    fig, axs=plt.subplots(2,1, figsize=(10.5,10), sharex='all', gridspec_kw=dict(height_ratios=(7,4)))
        
    divide_by_mu=True
    
    sfs=[0.0211, 1]
    labels=['"strawman"', "AI"]
    colors="tab:blue tab:orange tab:green tab:red 0.65".split()
    if abso=="Fe":
        dfs=df_gamma_strawman,
    for k in 0,:
        #fig, axs=plt.subplots(2,2, figsize=(12,8), sharex='all', gridspec_kw=dict(height_ratios=(6,4), width_ratios=(4,1.5)))
        dist_bins=[0,4]
        
        #axs[0].errorbar([],[], label="distance from nearest edge:", color='white')
        for i in range(len(dist_bins)-1):
            fs="full" if i<=3 else "none"
            bcs=[]
            sigmas=[]
            dsigmas=[]
            mus=[]
            dmus=[]
            for j in range(len(energy_bins)-1):
                dfq=dfs[k].query(f"E_truth>{energy_bins[j]} and E_truth<{energy_bins[j+1]} and E_reco>0")
                dfq=dfq.query(f"theta_mrad>{dist_bins[i]} and theta_mrad<{dist_bins[i+1]}")
                
                bcs.append((energy_bins[j]+energy_bins[j+1])/2)
                Eshower=dfq['E_reco']/sfs[k]
                Etruth=dfq.E_truth
            
                
                sf=1
                if not divide_by_mu:
                    a=Eshower/Etruth/sf-1
                    #print(a)
                    a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                else :
                    a=Eshower/sf/Etruth
                    a=a[(a>np.mean(a)-3*np.std(a))&(a<np.mean(a)+3*np.std(a))]
                #print(np.mean(a))
                sigma,dsigma,mu, dmu=res_calc(a, nsigma=2)
                sigmas.append(sigma)
                dsigmas.append(dsigma)
                mus.append(mu)
                dmus.append(dmu)
                #ymid=1
            method="strawman" if k==0 else "AI"
            axs[0].errorbar(np.array(bcs)*(1-i*.007), np.array(sigmas)*100/(np.array(mus)), np.array(dsigmas)/(np.array(mus))*100, 
                     label=f"ZDC sim ({method} recon)", marker='o', ls='', color=colors[i], fillstyle="full" if k==1 else "none")
            axs[1].errorbar(np.array(bcs)*(1-i*.007), (np.array(mus)-1)*100, np.array(dmus)*100, 
                 label=f"ZDC sim", marker='o', ls='', color=colors[i],fillstyle="full" if k==1 else "none")
            

            P0=[40]
            fnc = lambda E, a: np.sqrt(a**2/E)
            y=np.array(sigmas)
            dy=np.array(dsigmas)
            if divide_by_mu:
                y=y/np.array(mus)
                dy=dy/np.array(mus)
            bcs=np.array(bcs)
            slc=(bcs>10)&(bcs<80)
            P, cov = curve_fit(fnc,bcs[slc], y[slc], p0=P0, sigma=dy[slc])
            x=np.linspace(10, 300)
            axs[0].errorbar(x, fnc(x,*P)*100, ls=':' if k==0 else "--", color='tab:green', label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}$")
            print(labels, abso, f"fit: ${abs(P[0])*100:.1f}\%/\\sqrt{{E}}$")
            #axs[0][-1].errorbar([], [], label=f"fit: ${P[0]*100:.0f}\%/\\sqrt{{E}}\\oplus{P[1]*100:.1f}\%$", ls=':', color='tab:green')
        axs[0].set_ylim(0,18)

        

        
        x=np.linspace(10, 275, 100)
        
        axs[1].set_xlabel("$E_{\\rm truth}$ [GeV]")
        axs[1].set_ylim(-10, 10)
        if not divide_by_mu:
            axs[0].set_ylabel("$\\sigma[E_{\\rm reco}/E_{\\rm truth}]$ [%]", fontsize=20)
        else:
            #axs[0].set_ylabel("$\\sigma[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]/\\mu[\\frac{E_{\\rm reco}}{E_{\\rm truth}}]$ [%]", fontsize=20)
            axs[0].set_ylabel("$\\sigma[E_{\\rm reco}]/\\mu[E_{\\rm reco}]$ [%]", fontsize=20)
        
        axs[1].set_ylabel("$\\mu[E_{\\rm reco}]/E_{\\rm truth} -1$ [%]", fontsize=20)
        
        plt.subplots_adjust(hspace=0)
        
        axs[0].set_title(f'ZDC photon simulations,\nenergy reconstruction', fontsize=24)
        axs[0].set_xscale("log")
        if k==0:
            #dummy to ensure that the legend looks right
            axs[0].errorbar([],[],[], color='white', label=" ")
        
    axs[1].axhline(0, color='0.5', alpha=0.7, ls='--')
    #axs[0].errorbar(x, np.hypot(50/np.sqrt(x), 5), marker='', ls='--', lw=2, label='YR requirement:\n$50\%/\\sqrt{E}\\oplus 5\%$', color='tab:brown')
    if integrated:
        axs[0].legend(fontsize=16, ncol=2, framealpha=0)
    plt.sca(axs[0])
    plt.xlim(19, 300)
    axs[0].legend()
    axs[0].set_ylim(0, 6)
    write_geom(abso, 1, x=22)
    #plt.tight_layout()
#     plt.savefig(f"images/strawman_vs_AI_{abso}_integrated_gamma.pdf")
    
    plt.show()
# Out:
# ['"strawman"', 'AI'] Fe fit: $20.0\%/\sqrt{E}$

# %%
#check the position of the ZDC
dirs=[]
import glob, uproot as ur, awkward as ak
dirs.append("zdc_gamma_log10discrete_10_300GeV_0-0.23deg_unstaggered_11_23")
dirs.append("zdc_neutron_log10continuous_10GeV-300GeV_0.0deg-0.3deg_unstaggered_01_29_2024")
for dir in dirs:
    arrays=ur.open(glob.glob(f"/media/miguel/Elements/zdc_data/{dir}/*.root")[0] +":events").arrays()
    print(min(ak.flatten(arrays["ZDCHcalHitsReco.position.z"])))
# Out:
# 37522.25
# 35822.25

# %%
#Ryan's plot

# %%
#X-axis data:
energy_bins= '10 11  12  13  14  16  17  19  21  24  26  29  32  35  39  43  47  52 57  63  70  77  85  93 103 114 125 138 152 168 185 204 225 248 274 302'
energy_bins= np.array([float(a) for a in energy_bins.split()])
print(len(energy_bins))
sigmacut_photon_energy = [54.17080437, 63.50546177, 73.63455809, 86.7428004, 100.8440914, 117.7259186, 138.182721,
                        160.4270109, 187.2393247, 218.8182721, 255.163853]
sigmacut_pi0_energy = [54.3694141, 63.50546177, 73.83316783, 86.94141013, 100.6454816, 100.6454816, 117.3286991,
                     137.388282, 160.8242304, 187.040715, 218.8182721, 255.3624628]
#Left y-axis data:
    
photon_accuracy_copy = np.asarray([0.541151, 0.609476, 0.610571, 0.580496, 0.52372 , 0.442948,
       0.420962, 0.423926, 0.456044, 0.548684, 0.615457, 0.725877,
       0.848467, 0.924024, 0.966091, 0.985526, 0.990601, 0.993647,
       0.995297, 0.996323, 0.996472, 0.996616, 0.996722, 0.997569,
       0.996975, 0.997463, 0.997515, 0.997101, 0.996863, 0.997137,
       0.997117, 0.996359, 0.995006, 0.992846, 0.990898, 0.985716])
pi0_misidentification_copy = np.asarray([0.070509, 0.093674, 0.108761, 0.11199 , 0.109508, 0.095728,
       0.098996, 0.105305, 0.125843, 0.159009, 0.179288, 0.20852 ,
       0.233374, 0.25635 , 0.257732, 0.234116, 0.201395, 0.179329,
       0.146239, 0.130307, 0.10346 , 0.08894 , 0.070097, 0.060498,
       0.050006, 0.045752, 0.036144, 0.028828, 0.026024, 0.018129,
       0.019057, 0.014717, 0.013489, 0.011581, 0.010514, 0.011606])
sigmacut_photon_efficiency = np.asarray([0.9089693155, 0.9533988229, 0.9686861141, 0.9920778849, 0.9842185296, 0.9920778849,
                            0.9920778849, 1., 0.9764214371, 1., 0.9920778849])
sigmacut_pi0_efficiency = np.asarray([0.1518263496, 0.1205520052, 0.09725460851, 0.06963578404, 0.05398797821,0.05398797821,
                         0.04355447821, 0.03323448447, 0.02767844093, 0.02659931584, 0.02417796191, 0.02398642132])
                         
                         
#Right y-axis data:
fraction_one_photon_events_copy=[0.597003, 0.66697 , 0.747497, 0.82028 , 0.873219, 0.928848,
       0.915644, 0.823387, 0.727606, 0.619451, 0.560366, 0.473477,
       0.408982, 0.358437, 0.298994, 0.252053, 0.211001, 0.184357,
       0.147873, 0.131963, 0.104359, 0.089349, 0.070152, 0.060707,
       0.049801, 0.04549 , 0.034474, 0.02713 , 0.024955, 0.016412,
       0.016738, 0.013088, 0.011202, 0.009277, 0.006834, 0.00589]

fig, ax1 = plt.subplots()
plt.title("ZDC $\\pi^0/\\gamma$ classification")
fig.set_facecolor('w')

ax1.set_xlabel('$E_{truth}$ [GeV]')
ax1.set_ylabel('Efficiency of passing $\gamma$ selection', color='black')
ax1.plot(sigmacut_photon_energy, sigmacut_photon_efficiency, label='Simple $\sigma$ cut, $\gamma$', color = 'b', linestyle='dashed',alpha=.8)
ax1.plot(energy_bins, photon_accuracy_copy, label='GNN, $\gamma$', color='b', alpha=.8)
ax1.plot(sigmacut_pi0_energy, sigmacut_pi0_efficiency, label='Simple $\sigma$ cut, $\pi^0$', color = 'r', linestyle='dashed',alpha=.8)
ax1.plot(energy_bins, pi0_misidentification_copy, label='GNN, $\pi^0$', color='r',alpha=.8)
ax1.tick_params(axis='y', labelcolor='black')
ax1.set_yscale("log")
ax1.set_ylim(10**-2,)
ax1.set_xlim(45,255)

ax1.plot(energy_bins, fraction_one_photon_events_copy, label='$\\pi^0\\rightarrow\\gamma\\gamma$\nacceptance bottleneck', color='g',alpha=.8)
ax1.legend(loc='center right')
ax1.grid()

# ax2 = ax1.twinx()
# ax2.set_ylabel('Fraction of single $\gamma$ events', color='g')
# ax2.plot(energy_bins, fraction_one_photon_events_copy, label='GNN, $\pi^0$', color='g',alpha=.8)
# ax2.tick_params(axis='y', labelcolor='green')
# ax2.set_yscale("log")
# ax2.set_ylim(10**-2,)
# plt.savefig("images/classification_efficiency.pdf")
output_pdf = PdfPages('/home/ryan/ml_analysis/zdc_paper_plots/zdc_classification_efficiency.pdf')
output_pdf.savefig(fig)
output_pdf.close()
plt.show()
# Out:
# 36
