# %%
# %load_ext autoreload
# %autoreload 2

import sys  
sys.path.insert(0, 'functions')
sys.path.insert(0, 'training')

# %%
from Clusterer import *
from plotting import *
from data_functions import *

# %%
labels = ["1 Layer","3 Layers","9 Layers"]
dirs = ["HCal_0-110GeVLinear_17degFixed",
        "Segmentation3L_HCal_0-110GeVLinear_17degFixed",
        "Nine_Segmentation3L_HCal_0-110GeVLinear_17degFixed"]

Compare_Resolutions(dirs,labels)
Compare_Scales(dirs,labels)

# %%
labels = ["1 Layer","3 Layers","9 Layers","50 Layers"]
dirs = ["HCal_0-60GeVLogUniform20n20deg",
        "Segmentation3L_HCal_0-60GeVLogUniform20n20deg",
        "Nine_Segmentation3L_HCal_0-60GeVLogUniform20n20deg",
        "Fifty_Segmentation3L_HCal_0-60GeVLogUniform20n20deg"]

Compare_Resolutions(dirs,labels,logscale=True)
Compare_Scales(dirs,labels,logscale=True)
